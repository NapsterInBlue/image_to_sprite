# %%
# %pylab inline

import cv2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Overview

# %%
raw = cv2.imread('images/sneaky_fox.jpg')
raw = cv2.cvtColor(raw, cv2.COLOR_BGR2RGB)

# %%
raw.shape
# Out:
# (1080, 814, 3)

# %%
plt.imshow(raw);

# %%
from spritify import im_to_sprite

# %%
from spritify import mask_iterator, generate_mask_array

# %%
plt.imshow(im_to_sprite('images/sneaky_fox.jpg'))
